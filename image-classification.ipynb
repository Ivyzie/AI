# %% [markdown]
# Importing MobileNetV2

# %%
from keras.applications.mobilenet_v2 import MobileNetV2

model =  MobileNetV2(weights='imagenet')
#model.summary() #Uncomment this for long summary
#model expects input of (224 , 224 , 3)

# %% [markdown]
# Loading image

# %%
import numpy as np
from imageio import imread
from keras.applications.mobilenet_v2 import preprocess_input

data = np.empty((1, 224 , 224 , 3))
#first field means amount of images, last field means the colour channels
data[0] = imread('shiba.jpg')
data = preprocess_input(data)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14668\1569598709.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   data[0] = imread('shiba.jpg')

# %% [markdown]
# Classify the image

# %%
from keras.applications.mobilenet_v2 import decode_predictions
predictions = model.predict(data)
for name, desc, score in decode_predictions(predictions, top = 5)[0]:
    print('- {} ({:.2f}%%)'.format(desc, 100 * score))
# Out:
# 1/1 [==============================] - 0s 36ms/step
# - Siberian_husky (20.55%%)
# - Eskimo_dog (17.49%%)
# - basenji (7.27%%)
# - chow (4.27%%)
# - Norwegian_elkhound (4.21%%)
# - malamute (4.17%%)
# - dingo (2.04%%)
# - Pomeranian (1.43%%)
# - Pembroke (0.92%%)
# - schipperke (0.86%%)

# %%
predictions
# Out:
# array([[8.31095167e-05, 3.70912967e-05, 7.73802749e-05, 3.92017027e-05,
#         3.08201343e-05, 5.22571972e-05, 5.21778675e-05, 5.95002384e-05,
#         3.20815052e-05, 1.87430647e-04, 1.18553100e-04, 1.88664664e-04,
#         1.11276073e-04, 8.79187937e-05, 2.30410544e-04, 1.39778989e-04,
#         2.93005232e-05, 4.51536675e-04, 4.81821480e-05, 6.55695912e-05,
#         2.80163018e-04, 2.96143462e-05, 7.87736863e-05, 1.67085920e-04,
#         9.47070948e-05, 4.97086730e-05, 9.30286405e-05, 1.21297970e-04,
#         5.23613053e-05, 1.91866184e-05, 4.28977910e-05, 1.10294670e-04,
#         1.56509501e-04, 1.15976371e-04, 1.50891850e-04, 5.44489703e-05,
#         7.54238717e-05, 2.75062994e-05, 1.42698540e-04, 7.47005179e-05,
#         4.25439153e-04, 2.32506427e-04, 1.40040764e-04, 3.40762490e-05,
#         1.26449813e-04, 4.44367688e-05, 8.69376701e-04, 8.67489507e-05,
#         9.15928322e-05, 3.27717775e-04, 3.11844124e-05, 1.12490947e-04,
# ...

# %%
np.argmax(predictions, axis = 1)
# Out:
# array([400], dtype=int64)

# %%
predictions[0][400]
# Out:
# 0.6100235
